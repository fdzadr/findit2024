# %% [markdown]
# # Persiapan

# %%
# Import Library
import pandas as pd
print(pd.__version__)
# Out:
# 2.1.3

# %%
# Import Data
df = pd.read_csv('data-analytics-competition-find-it-2024/train_features.csv')
df
# Out:
#       tahun_kelahiran pendidikan status_pernikahan   pendapatan  \
# 0                1979    Sarjana   Rencana Menikah          NaN
# 1                1950    Sarjana   Rencana Menikah   84063000.0
# 2                1966    Sarjana           Menikah  127532564.0
# 3                1961   Magister   Rencana Menikah  165579620.0
# 4                1970    Sarjana   Rencana Menikah  117703159.0
# ...               ...        ...               ...          ...
# 3812             1955   Magister           Menikah   78199470.0
# 3813             1947     Doktor   Rencana Menikah  109306000.0
# 3814             1974   Magister           Menikah  104621000.0
# 3815             1957        SMA   Rencana Menikah  110850000.0
# 3816             1961    Sarjana           Menikah  130512000.0
#
#       jumlah_anak_balita  jumlah_anak_remaja  terakhir_belanja  belanja_buah  \
# 0                    0.0                 1.0               NaN       50575.0
# ...

# %% [markdown]
# # Cek NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3817 entries, 0 to 3816
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   tahun_kelahiran          3817 non-null   int64
#  1   pendidikan               3628 non-null   object
#  2   status_pernikahan        3605 non-null   object
#  3   pendapatan               3627 non-null   float64
#  4   jumlah_anak_balita       3627 non-null   float64
#  5   jumlah_anak_remaja       3613 non-null   float64
#  6   terakhir_belanja         3645 non-null   float64
#  7   belanja_buah             3636 non-null   float64
#  8   belanja_daging           3639 non-null   float64
#  9   belanja_ikan             3624 non-null   float64
#  10  belanja_kue              3603 non-null   float64
#  11  pembelian_diskon         3639 non-null   float64
#  12  pembelian_web            3652 non-null   float64
# ...

# %% [markdown]
# # Cek Unique Value setiap kolom

# %%
df['tahun_kelahiran'].unique()
# Out:
# array([1979, 1950, 1966, 1961, 1970, 1952, 1963, 1959, 1957, 1975, 1953,
#        1968, 1983, 1977, 1973, 1969, 1980, 1965, 1960, 1982, 1971, 1972,
#        1958, 1944, 1986, 1962, 1967, 1984, 1976, 1964, 1954, 1956, 1978,
#        1991, 1981, 1946, 1974, 1947, 1955, 1989, 1945, 1948, 1990, 1951,
#        1988, 1949, 1985, 1943, 1996, 1987, 1909, 1993, 1992, 1925, 1912,
#        1999, 1941, 1995, 1994, 1916, 1942, 1998, 1899, 1902, 1922, 2000,
#        1918, 1920, 1997, 1929, 1940, 1932, 1924, 1900, 1914, 1908],
#       dtype=int64)

# %%
df['pendidikan'].unique()
# Out:
# array(['Sarjana', 'Magister', 'SMA', 'SMP', 'Doktor', nan, '5'],
#       dtype=object)

# %%
df['status_pernikahan'].unique()
# Out:
# array(['Rencana Menikah', 'Menikah', 'Sendiri', 'Cerai', nan,
#        'Cerai Mati', '5'], dtype=object)

# %%
df['pendapatan'].unique()
# Out:
# array([           nan, 8.40630000e+07, 1.27532564e+08, ...,
#        1.04621000e+08, 1.10850000e+08, 1.30512000e+08])

# %%
df['jumlah_anak_balita'].unique()
# Out:
# array([ 0., nan,  1.,  2.])

# %%
df['jumlah_anak_remaja'].unique()
# Out:
# array([ 1., nan,  0.,  2.])

# %%
df['terakhir_belanja'].unique()
# Out:
# array([ nan,  70.,  45.,  90.,  78.,   9.,  96.,  21.,  26.,  67.,  59.,
#         57.,   5.,  65.,  61.,  25.,  16.,   0.,  50.,  69.,  84.,  56.,
#         54.,  17.,  51.,  29.,  73.,  60.,  87.,  62.,  41.,  35.,   3.,
#         36.,  58.,  64.,  55.,  12.,  19.,  30.,  28.,  11., 114.,   4.,
#         76.,  85.,  15.,  80.,  81.,  37.,  47.,  18.,  20.,   6.,  77.,
#         22.,  32.,  75.,  43.,  31.,  23.,  44.,  66.,  68.,  79.,  99.,
#         39.,  46.,  33.,  27.,   8.,  14., 100.,  91.,  49.,  92.,  52.,
#          7.,  48.,  82.,  72.,  89.,  34.,  63.,  94.,  86.,  74.,  53.,
#         13.,  71.,  83.,  38.,   1.,  97.,  88.,  93.,  40.,   2.,  24.,
#        105.,  42.,  10., 102., 103.,  95., 101., 106., 128.,  98., 104.,
#        108., 122., 112., 124.])

# %%
df['belanja_buah'].unique()
# Out:
# array([ 50575.,   6069., 117611., ...,   2545.,  37316., 329749.])

# %%
df['belanja_daging'].unique()
# Out:
# array([260967.,  44506., 265460., ..., 729052.,  25977., 600831.])

# %%
df['belanja_ikan'].unique()
# Out:
# array([ 50575.,  80920.,  96341., ...,  45582.,   3856., 420784.])

# %%
df['belanja_kue'].unique()
# Out:
# array([ 20230., 145573., 125868., ...,  11880.,  51913.,   5784.])

# %%
df['pembelian_diskon'].unique()
# Out:
# array([ 2.,  9.,  1.,  0.,  7.,  4.,  3., nan,  6.,  5., 12.,  8., 20.,
#        10., 13., 19., 14., 16., 11.])

# %%
df['pembelian_web'].unique()
# Out:
# array([ 2.,  6.,  1.,  7.,  4., nan,  9.,  8., 10.,  5.,  3.,  0., 12.,
#        11., 14., 13., 27., 17., 30.])

# %%
df['pembelian_toko'].unique()
# Out:
# array([ 5.,  4.,  7.,  8.,  2.,  6.,  1., 12.,  0.,  3., 13., nan,  9.,
#        10., 11., 15., 14., 17., 16.])

# %%
df['keluhan'].unique()
# Out:
# array([ 0., nan,  1.])

# %%
df['tanggal_menjadi_anggota'].unique()
# Out:
# array(['2014-05-05', '2013-03-17', nan, '2013-05-03', '2013-11-21',
#        '2012-11-14', '2013-06-23', '2012-10-06', '2013-02-11',
#        '2014-03-28', '2012-11-10', '2013-05-02', '2013-01-18',
#        '2014-01-10', '2014-03-14', '2014-02-18', '2013-07-06',
#        '2014-02-27', '2014-01-25', '2013-07-05', '2013-05-08',
#        '2013-03-30', '2014-06-11', '2013-03-31', '2012-11-06',
#        '2013-04-14', '2013-03-12', '2013-05-31', '2013-05-17',
#        '2012-09-13', '2013-09-12', '2014-05-14', '2014-05-09',
#        '2013-10-15', '2013-09-06', '2012-12-10', '2013-04-13',
#        '2014-03-17', '2013-08-08', '2012-08-19', '2013-01-16',
#        '2014-05-23', '2013-03-29', '2014-06-27', '2012-09-06',
#        '2013-09-02', '2013-02-19', '2013-02-10', '2013-05-26',
#        '2014-03-03', '2013-04-07', '2014-05-26', '2014-01-26',
#        '2013-12-18', '2014-01-21', '2013-08-19', '2013-10-17',
#        '2014-03-20', '2013-07-02', '2013-10-13', '2013-12-27',
# ...

# %% [markdown]
# # Fill NaN dengan mean yang di-floor untuk non object dan isi dengan modus untuk object

# %%
import math

def fill_value(df):
    '''
    Isi setiap value yang null
    Jika kolomnya bertipe Numerik maka isi dengan mean
    lain kolomnya bertipe Kategorikal maka isi dengan nilai yang frekuensinya paling banyak
    '''

    '''
    tahun_kelahiran              int64
    pendidikan                  object
    status_pernikahan           object
    pendapatan                 float64
    jumlah_anak_balita         float64
    jumlah_anak_remaja         float64
    terakhir_belanja           float64
    belanja_buah               float64
    belanja_daging             float64
    belanja_ikan               float64
    belanja_kue                float64
    pembelian_diskon           float64
    pembelian_web              float64
    pembelian_toko             float64
    keluhan                    float64
    tanggal_menjadi_anggota     object
    '''

    df['tahun_kelahiran'] = df['tahun_kelahiran'].fillna(math.floor(df['tahun_kelahiran'].mean()))
    df['pendidikan'] = df['pendidikan'].replace('5', pd.NA) # Mengganti nilai '5' dengan NaN
    df['pendidikan'] = df['pendidikan'].fillna(df['pendidikan'].mode()[0]) # Mengisi nilai NaN dengan modus
    df['status_pernikahan'] = df['status_pernikahan'].replace('5', pd.NA)
    df['status_pernikahan'] = df['status_pernikahan'].fillna(df['status_pernikahan'].mode()[0])
    df['pendapatan'] = df['pendapatan'].fillna(math.floor(df['pendapatan'].mean()))
    df['jumlah_anak_balita'] = df['jumlah_anak_balita'].fillna(math.floor(df['jumlah_anak_balita'].mean()))
    df['jumlah_anak_remaja'] = df['jumlah_anak_remaja'].fillna(math.floor(df['jumlah_anak_remaja'].mean()))
    df['terakhir_belanja'] = df['terakhir_belanja'].fillna(math.floor(df['terakhir_belanja'].mean()))
    df['belanja_buah'] = df['belanja_buah'].fillna(math.floor(df['belanja_buah'].mean()))
    df['belanja_daging'] = df['belanja_daging'].fillna(math.floor(df['belanja_daging'].mean()))
    df['belanja_ikan'] = df['belanja_ikan'].fillna(math.floor(df['belanja_ikan'].mean()))
    df['belanja_kue'] = df['belanja_kue'].fillna(math.floor(df['belanja_kue'].mean()))
    df['pembelian_diskon'] = df['pembelian_diskon'].fillna(math.floor(df['pembelian_diskon'].mean()))
    df['pembelian_web'] = df['pembelian_web'].fillna(math.floor(df['pembelian_web'].mean()))
    df['pembelian_toko'] = df['pembelian_toko'].fillna(math.floor(df['pembelian_toko'].mean()))
    df['keluhan'] = df['keluhan'].fillna(math.floor(df['keluhan'].mean()))
    df['tanggal_menjadi_anggota'] = df['tanggal_menjadi_anggota'].fillna(df['tanggal_menjadi_anggota'].mode()[0])

# %%
fill_value(df)
df
# Out:
#       tahun_kelahiran pendidikan status_pernikahan   pendapatan  \
# 0                1979    Sarjana   Rencana Menikah  114483170.0
# 1                1950    Sarjana   Rencana Menikah   84063000.0
# 2                1966    Sarjana           Menikah  127532564.0
# 3                1961   Magister   Rencana Menikah  165579620.0
# 4                1970    Sarjana   Rencana Menikah  117703159.0
# ...               ...        ...               ...          ...
# 3812             1955   Magister           Menikah   78199470.0
# 3813             1947     Doktor   Rencana Menikah  109306000.0
# 3814             1974   Magister           Menikah  104621000.0
# 3815             1957        SMA   Rencana Menikah  110850000.0
# 3816             1961    Sarjana           Menikah  130512000.0
#
#       jumlah_anak_balita  jumlah_anak_remaja  terakhir_belanja  belanja_buah  \
# 0                    0.0                 1.0              47.0       50575.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3817 entries, 0 to 3816
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   tahun_kelahiran          3817 non-null   int64
#  1   pendidikan               3817 non-null   object
#  2   status_pernikahan        3817 non-null   object
#  3   pendapatan               3817 non-null   float64
#  4   jumlah_anak_balita       3817 non-null   float64
#  5   jumlah_anak_remaja       3817 non-null   float64
#  6   terakhir_belanja         3817 non-null   float64
#  7   belanja_buah             3817 non-null   float64
#  8   belanja_daging           3817 non-null   float64
#  9   belanja_ikan             3817 non-null   float64
#  10  belanja_kue              3817 non-null   float64
#  11  pembelian_diskon         3817 non-null   float64
#  12  pembelian_web            3817 non-null   float64
# ...

# %%
df['pendidikan'].unique()
# Out:
# array(['Sarjana', 'Magister', 'SMA', 'SMP', 'Doktor'], dtype=object)

# %%
df['status_pernikahan'].unique()
# Out:
# array(['Rencana Menikah', 'Menikah', 'Sendiri', 'Cerai', 'Cerai Mati'],
#       dtype=object)

# %%
df['jumlah_anak_balita'].unique()
# Out:
# array([0., 1., 2.])

# %%
df['jumlah_anak_remaja'].unique()
# Out:
# array([1., 0., 2.])

# %% [markdown]
# # Visualisasi

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.hist(df['tahun_kelahiran'], bins=10, color='skyblue', edgecolor='black')
plt.title('Distribusi Tahun Kelahiran')
plt.xlabel('Tahun Kelahiran')
plt.ylabel('Jumlah')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8, 6))
df['pendidikan'].value_counts().plot(kind='bar', color='skyblue', edgecolor='black')
plt.title('Distribusi Tingkat Pendidikan')
plt.xlabel('Tingkat Pendidikan')
plt.ylabel('Jumlah')
plt.xticks(rotation=45)  
plt.grid(axis='y')
plt.show()

# %%
plt.figure(figsize=(8, 6))
df['status_pernikahan'].value_counts().plot(kind='bar', color='skyblue', edgecolor='black')
plt.title('Distribusi Status Pernikahan')
plt.xlabel('Status Pernikahan')
plt.ylabel('Jumlah')
plt.xticks(rotation=45)  
plt.grid(axis='y')
plt.show()

# %%
plt.figure(figsize=(8, 6))
df['pendapatan'].value_counts().sort_index().plot(kind='line', color='skyblue', marker='o', markerfacecolor='blue', markersize=8)
plt.title('Distribusi Pendapatan')
plt.xlabel('Pendapatan')
plt.ylabel('Jumlah')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.show()

# %%
plt.figure(figsize=(8, 6))
df['jumlah_anak_balita'].value_counts().plot(kind='bar', color='skyblue', edgecolor='black')
plt.title('Distribusi Jumlah Anak Balita')
plt.xlabel('Jumlah Anak Balita')
plt.ylabel('Jumlah')
plt.xticks(rotation=45)  
plt.grid(axis='y')
plt.show()

# %%
plt.figure(figsize=(8, 6))
df['jumlah_anak_remaja'].value_counts().plot(kind='bar', color='skyblue', edgecolor='black')
plt.title('Distribusi Jumlah Anak Remaja')
plt.xlabel('Jumlah Anak Remaja')
plt.ylabel('Jumlah')
plt.xticks(rotation=45)  
plt.grid(axis='y')
plt.show()

# %%
plt.figure(figsize=(8, 6))
df['pembelian_diskon'].value_counts().plot(kind='bar', color='skyblue', edgecolor='black')
plt.title('Distribusi Pembelian Diskon')
plt.xlabel('Pembelian Diskon')
plt.ylabel('Jumlah')
plt.xticks(rotation=45)  
plt.grid(axis='y')
plt.show()

# %%
plt.figure(figsize=(8, 6))
df['pembelian_web'].value_counts().plot(kind='bar', color='skyblue', edgecolor='black')
plt.title('Distribusi Pembelian Web')
plt.xlabel('Pembelian Web')
plt.ylabel('Jumlah')
plt.xticks(rotation=45)  
plt.grid(axis='y')
plt.show()

# %%
plt.figure(figsize=(8, 6))
df['pembelian_toko'].value_counts().plot(kind='bar', color='skyblue', edgecolor='black')
plt.title('Distribusi Pembelian Toko')
plt.xlabel('Pembelian Toko')
plt.ylabel('Jumlah')
plt.xticks(rotation=45)  
plt.grid(axis='y')
plt.show()

# %%
plt.figure(figsize=(8, 6))
df['keluhan'].value_counts().plot(kind='bar', color='skyblue', edgecolor='black')
plt.title('Distribusi Keluhan')
plt.xlabel('Keluhan')
plt.ylabel('Jumlah')
plt.xticks(rotation=45)  
plt.grid(axis='y')
plt.show()

# %%
plt.figure(figsize=(10, 6))
df['tanggal_menjadi_anggota'] = pd.to_datetime(df['tanggal_menjadi_anggota'])  # Pastikan kolom tanggal diubah menjadi tipe data datetime
df['tanggal_menjadi_anggota'].value_counts().sort_index().plot(kind='line', marker='o', color='green')
plt.title('Grafik Tanggal Menjadi Anggota')
plt.xlabel('Tanggal')
plt.ylabel('Jumlah Anggota')
plt.grid(True)
plt.show()

# %% [markdown]
# # Normalisasi

# %%
def normalize(df):
    # Normalisasi setiap kolom yang bertipe numerik
    # Gunakan MinMaxScaler
    from sklearn.preprocessing import MinMaxScaler, OrdinalEncoder, StandardScaler
    scaler = MinMaxScaler()
    ordinal = OrdinalEncoder()
    df[['tahun_kelahiran', 'pendapatan', 'jumlah_anak_balita', 'jumlah_anak_remaja', 'terakhir_belanja', 'belanja_buah', 'belanja_daging', 'belanja_ikan', 'belanja_kue', 'pembelian_diskon', 'pembelian_web', 'pembelian_toko', 'keluhan']] = scaler.fit_transform(df[['tahun_kelahiran', 'pendapatan', 'jumlah_anak_balita', 'jumlah_anak_remaja', 'terakhir_belanja', 'belanja_buah', 'belanja_daging', 'belanja_ikan', 'belanja_kue', 'pembelian_diskon', 'pembelian_web', 'pembelian_toko', 'keluhan']])
    df[['pendidikan', 'status_pernikahan']]=ordinal.fit_transform(df[['pendidikan', 'status_pernikahan']])

# %%
normalize(df)
df
# Out:
#       tahun_kelahiran  pendidikan  status_pernikahan  pendapatan  \
# 0            0.792079         4.0                3.0    0.333760
# 1            0.504950         4.0                3.0    0.240962
# 2            0.663366         4.0                2.0    0.373568
# 3            0.613861         1.0                3.0    0.489632
# 4            0.702970         4.0                3.0    0.343583
# ...               ...         ...                ...         ...
# 3812         0.554455         1.0                2.0    0.223075
# 3813         0.475248         0.0                3.0    0.317967
# 3814         0.742574         1.0                2.0    0.303675
# 3815         0.574257         2.0                3.0    0.322677
# 3816         0.613861         4.0                2.0    0.382656
#
#       jumlah_anak_balita  jumlah_anak_remaja  terakhir_belanja  belanja_buah  \
# 0                    0.0                 0.5          0.367188      0.127551
# ...

# %% [markdown]
# # Drop kolom 'tanggal_menjadi_anggota'

# %%
df.drop(columns=['tanggal_menjadi_anggota'], inplace=True)
df
# Out:
#       tahun_kelahiran  pendidikan  status_pernikahan  pendapatan  \
# 0            0.792079         4.0                3.0    0.333760
# 1            0.504950         4.0                3.0    0.240962
# 2            0.663366         4.0                2.0    0.373568
# 3            0.613861         1.0                3.0    0.489632
# 4            0.702970         4.0                3.0    0.343583
# ...               ...         ...                ...         ...
# 3812         0.554455         1.0                2.0    0.223075
# 3813         0.475248         0.0                3.0    0.317967
# 3814         0.742574         1.0                2.0    0.303675
# 3815         0.574257         2.0                3.0    0.322677
# 3816         0.613861         4.0                2.0    0.382656
#
#       jumlah_anak_balita  jumlah_anak_remaja  terakhir_belanja  belanja_buah  \
# 0                    0.0                 0.5          0.367188      0.127551
# ...

# %%
df.describe(include='all')
# Out:
#        tahun_kelahiran   pendidikan  status_pernikahan   pendapatan  \
# count      3817.000000  3817.000000        3817.000000  3817.000000
# mean          0.681425     2.653131           2.771810     0.333760
# std           0.116516     1.540742           1.019496     0.129235
# min           0.000000     0.000000           0.000000     0.000000
# 25%           0.594059     1.000000           2.000000     0.236525
# 50%           0.683168     4.000000           3.000000     0.333760
# 75%           0.762376     4.000000           4.000000     0.435862
# max           1.000000     4.000000           4.000000     1.000000
#
#        jumlah_anak_balita  jumlah_anak_remaja  terakhir_belanja  belanja_buah  \
# count         3817.000000         3817.000000       3817.000000   3817.000000
# mean             0.139245            0.167409          0.368915      0.150827
# std              0.232760            0.243105          0.206652      0.182211
# ...

# %% [markdown]
# # Split Data

# %%
from sklearn.model_selection import train_test_split

y = pd.read_csv('data-analytics-competition-find-it-2024/train_labels.csv')
y
# Out:
#       jumlah_promosi
# 0                  2
# 1                  0
# 2                  1
# 3                  4
# 4                  4
# ...              ...
# 3812               5
# 3813               1
# 3814               0
# 3815               0
# 3816               0
#
# [3817 rows x 1 columns]

# %%
y['jumlah_promosi'].unique()
# Out:
# array([2, 0, 1, 4, 5, 3, 6], dtype=int64)

# %%
X_train, X_test, y_train, y_test = train_test_split(df, y, test_size=0.05)

# %% [markdown]
# # Modelling

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import f1_score

dt = DecisionTreeClassifier(random_state=24)
dt.fit(X_train, y_train)

prediction = dt.predict(X_test)
print(f1_score(prediction, y_test, average='macro'))
# Out:
# 0.5448418703634749

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(random_state=24)
rf.fit(X_train, y_train)

prediction = rf.predict(X_test)
print(f1_score(prediction, y_test, average='macro'))
# Out:
# d:\Python\python311\Lib\site-packages\sklearn\base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# 0.7531757646263316

# %%
from sklearn.svm import SVC

svc = SVC(kernel='linear', random_state=24)
svc.fit(X_train, y_train)

prediction = svc.predict(X_test)
print(f1_score(prediction, y_test, average='macro'))
# Out:
# d:\Python\python311\Lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.21030826637469088

# %%
from sklearn.ensemble import GradientBoostingClassifier

gbc = GradientBoostingClassifier(random_state=24)
gbc.fit(X_train, y_train)

prediction = gbc.predict(X_test)
print(f1_score(prediction, y_test, average='macro'))
# Out:
# d:\Python\python311\Lib\site-packages\sklearn\ensemble\_gb.py:424: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.5630276846262101

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier()
knn.fit(X_train, y_train)

prediction = knn.predict(X_test)
print(f1_score(prediction, y_test, average='macro'))
# Out:
# 0.4470901333601563
# d:\Python\python311\Lib\site-packages\sklearn\neighbors\_classification.py:233: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)

# %%
from sklearn.neural_network import MLPClassifier

mlp = MLPClassifier(random_state=24)
mlp.fit(X_train, y_train)

prediction = mlp.predict(X_test)
print(f1_score(prediction, y_test, average='macro'))
# Out:
# d:\Python\python311\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1102: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.31419847979032506
# d:\Python\python311\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
from sklearn.linear_model import LogisticRegression

logreg = LogisticRegression(random_state=24)
logreg.fit(X_train, y_train)

prediction = logreg.predict(X_test)
print(f1_score(prediction, y_test, average='macro'))
# Out:
# d:\Python\python311\Lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.21630695915761677
# d:\Python\python311\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
from sklearn.naive_bayes import GaussianNB

nb = GaussianNB()
nb.fit(X_train, y_train)

prediction = nb.predict(X_test)
print(f1_score(prediction, y_test, average='macro'))
# Out:
# 0.16977618126554297
# d:\Python\python311\Lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
import xgboost as xgb

xgb_model = xgb.XGBClassifier(random_state=24)
xgb_model.fit(X_train, y_train)

prediction = xgb_model.predict(X_test)
print(f1_score(prediction, y_test, average='macro'))
# Out:
# 0.7164591081329341

# %%
import tensorflow as tf

model = tf.keras.Sequential([
    tf.keras.layers.Dense(128, activation='relu', input_shape=(X_train.shape[1],)),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(7, activation='softmax')
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.fit(X_train, y_train, epochs=10, batch_size=32, validation_data=(X_test, y_test), verbose=2)

prediction = model.predict(X_test)
prediction_classes = prediction.argmax(axis=-1)
print(f1_score(prediction_classes, y_test, average='macro'))
# Out:
# Epoch 1/10
# 114/114 - 2s - loss: 1.8651 - accuracy: 0.2645 - val_loss: 1.8624 - val_accuracy: 0.2356 - 2s/epoch - 21ms/step
# Epoch 2/10
# 114/114 - 0s - loss: 1.7990 - accuracy: 0.3006 - val_loss: 1.8172 - val_accuracy: 0.3194 - 419ms/epoch - 4ms/step
# Epoch 3/10
# 114/114 - 0s - loss: 1.7512 - accuracy: 0.3235 - val_loss: 1.7887 - val_accuracy: 0.3194 - 419ms/epoch - 4ms/step
# Epoch 4/10
# 114/114 - 0s - loss: 1.7149 - accuracy: 0.3472 - val_loss: 1.7736 - val_accuracy: 0.3351 - 460ms/epoch - 4ms/step
# Epoch 5/10
# 114/114 - 0s - loss: 1.6871 - accuracy: 0.3643 - val_loss: 1.7647 - val_accuracy: 0.3246 - 431ms/epoch - 4ms/step
# Epoch 6/10
# 114/114 - 0s - loss: 1.6621 - accuracy: 0.3723 - val_loss: 1.7200 - val_accuracy: 0.3560 - 431ms/epoch - 4ms/step
# Epoch 7/10
# 114/114 - 0s - loss: 1.6429 - accuracy: 0.3847 - val_loss: 1.7527 - val_accuracy: 0.3089 - 469ms/epoch - 4ms/step
# Epoch 8/10
# ...

# %%
from sklearn.model_selection import GridSearchCV

param_grid_rfr = {
    'n_estimators': [50, 100, 150],
    'max_depth': [None, 10, 20],
    'max_features': ['sqrt'],
    'random_state': [42]
}

param_grid_xg = {
    'max_depth': [3, 5, 7],
    'learning_rate': [0.1, 0.01, 0.001],
    'n_estimators': [50, 100, 150],
}

grid_rfr = GridSearchCV(
    RandomForestClassifier(),
    param_grid=param_grid_rfr,
    n_jobs=-1,
    cv=2,
    verbose=1
)

grid_xg = GridSearchCV(
    estimator=xgb_model, 
    param_grid=param_grid_xg,  
    cv=5)

# %%
grid_rfr.fit(X_train, y_train)

best_rfr_model = grid_rfr.best_estimator_
best_rfr_params = grid_rfr.best_params_

y_pred_rfr = best_rfr_model.predict(X_test)

print(f1_score(y_test, y_pred_rfr, average='macro'))
# Out:
# Fitting 2 folds for each of 9 candidates, totalling 18 fits
# d:\Python\python311\Lib\site-packages\sklearn\base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# 0.741942812377595

# %%
grid_xg.fit(X_train, y_train)

best_xg_model = grid_xg.best_estimator_
best_xg_params = grid_xg.best_params_

y_pred_xg = best_xg_model.predict(X_test)

print(f1_score(y_test, y_pred_xg, average='macro'))
# Out:
# 0.7100698321286558

# %% [markdown]
# # Test Data

# %%
df_test = pd.read_csv('data-analytics-competition-find-it-2024/test_features.csv')
fill_value(df_test)

# %%
df_test=df_test.drop(columns=['tanggal_menjadi_anggota', 'ID'])

df_test
# Out:
#       tahun_kelahiran pendidikan status_pernikahan   pendapatan  \
# 0                1957    Sarjana   Rencana Menikah  120660151.0
# 1                1968     Doktor           Menikah  163551821.0
# 2                1968        SMA           Menikah   29857000.0
# 3                1971     Doktor           Menikah  117949098.0
# 4                1974    Sarjana   Rencana Menikah  164761134.0
# ...               ...        ...               ...          ...
# 3813             1984   Magister           Sendiri   66320000.0
# 3814             1972    Sarjana           Menikah  159651946.0
# 3815             1968   Magister   Rencana Menikah   84058923.0
# 3816             1966    Sarjana   Rencana Menikah  106301000.0
# 3817             1973    Sarjana           Menikah  140353000.0
#
#       jumlah_anak_balita  jumlah_anak_remaja  terakhir_belanja  belanja_buah  \
# 0                    0.0                 1.0              63.0      122277.0
# ...

# %%
normalize(df_test)
df_test
# Out:
#       tahun_kelahiran  pendidikan  status_pernikahan  pendapatan  \
# 0            0.555556         4.0                3.0    0.090318
# 1            0.649573         0.0                2.0    0.123242
# 2            0.649573         2.0                2.0    0.020617
# 3            0.675214         0.0                2.0    0.088237
# 4            0.700855         4.0                3.0    0.124171
# ...               ...         ...                ...         ...
# 3813         0.786325         1.0                4.0    0.048606
# 3814         0.683761         4.0                2.0    0.120249
# 3815         0.649573         1.0                3.0    0.062223
# 3816         0.632479         4.0                3.0    0.079296
# 3817         0.692308         4.0                2.0    0.105435
#
#       jumlah_anak_balita  jumlah_anak_remaja  terakhir_belanja  belanja_buah  \
# 0                    0.0                 0.5          0.473684      0.299225
# ...

# %%
result=grid_rfr.predict(df_test)

result=result.astype('int')

# %%
sub = pd.read_csv('data-analytics-competition-find-it-2024/submission_format.csv')

sub['jumlah_promosi']=result

sub
# Out:
#         ID  jumlah_promosi
# 0     2241               0
# 1     2274               0
# 2     1107               2
# 3     4478               0
# 4     5080               4
# ...    ...             ...
# 3813   271               0
# 3814  3334               1
# 3815  3478               0
# 3816    89               0
# 3817  2151               6
#
# [3818 rows x 2 columns]

# %%
# sub.to_csv('result.csv', index=False)

# %%
# Semangat kawan!
